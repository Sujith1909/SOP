# %% [markdown]
# # Data collection

# %%
import pandas as pd

# %%
df = pd.read_csv('ipl2019_final.csv')

# %%
df
# Out:
#        Over_No Over_Score                         Short_comm  \
# 0         19.6          w         ['Malinga to Thakur, OUT']
# 1         19.5          2      ['Malinga to Thakur, 2 runs']
# 2         19.4          w  ['Malinga to Watson, 1 run, OUT']
# 3         19.3          2      ['Malinga to Watson, 2 runs']
# 4         19.2          1       ['Malinga to Jadeja, 1 run']
# ...        ...        ...                                ...
# 13516      0.5          4     ['Chahar to Patel, FOUR runs']
# 13517      0.4          0        ['Chahar to Patel, no run']
# 13518      0.3          0        ['Chahar to Patel, no run']
# 13519      0.2          0        ['Chahar to Patel, no run']
# 13520      0.1          1         ['Chahar to Kohli, 1 run']
#
#                                               Commentary  \
# 0      Mumbai Indians win IPL 2019!  Slower ball, yor...
# 1      full toss on leg, and swiped away to deep back...
# 2      yorker, just outside off, and slapped to deep ...
# 3      yorker, just outside leg, and hammered to wide...
# 4      low full toss on middle, and drilled back to M...
# ...                                                  ...
# 13516  misfield by by mid-off  too full and Parthiv c...
# 13517  fuller and straighter, Parthiv wants to drive,...
# 13518  good bowling, keeps it wide of off stump but w...
# 13519  back of a length ball, given some width outsid...
# 13520  strays on the pads first ball and Kohli flicks...
#
#                                                Bold_Comm Innings_ID  Ball_ID  \
# 0      ['Mumbai Indians win IPL 2019!', 'Was that goi...  1181768-1        0
# 1                    ['CSK need two off the final ball']  1181768-1        1
# 2                                          ['Dramatic!']  1181768-1        2
# 3                                                     []  1181768-1        3
# 4                                                     []  1181768-1        4
# ...                                                  ...        ...      ...
# 13516                         ['misfield by by mid-off']  1175356-2       99
# 13517                                                 []  1175356-2      100
# 13518                                                 []  1175356-2      101
# 13519                                                 []  1175356-2      102
# 13520                                                 []  1175356-2      103
#
#        Match_ID
# 0       1181768
# 1       1181768
# 2       1181768
# 3       1181768
# 4       1181768
# ...         ...
# 13516   1175356
# 13517   1175356
# 13518   1175356
# 13519   1175356
# 13520   1175356
#
# [13521 rows x 8 columns]

# %%
df = df['Commentary']

# %%
df
# Out:
# 0        Mumbai Indians win IPL 2019!  Slower ball, yor...
# 1        full toss on leg, and swiped away to deep back...
# 2        yorker, just outside off, and slapped to deep ...
# 3        yorker, just outside leg, and hammered to wide...
# 4        low full toss on middle, and drilled back to M...
#                                ...
# 13516    misfield by by mid-off  too full and Parthiv c...
# 13517    fuller and straighter, Parthiv wants to drive,...
# 13518    good bowling, keeps it wide of off stump but w...
# 13519    back of a length ball, given some width outsid...
# 13520    strays on the pads first ball and Kohli flicks...
# Name: Commentary, Length: 13521, dtype: object

# %%
a = []
for i in df[:]:
    a.append(i)

# %%
with open('TestingOnIPL.txt', 'w') as f:
    for i in a:
        f.write(i)
        f.write('\n')

# %%
fp = open('TestingOnIPL.txt','r')
for i in fp:
    print(i)
# Out:
# Mumbai Indians win IPL 2019!  Slower ball, yorker on middle, and the leg-side swipe has been missed by the batsman. Malinga appeals, and umpire Menon raises his finger.  Was that going down leg side?  We'll never know since Raina had used his review. Lasith Malinga has redeemed himself after that 20-run over.
#
# full toss on leg, and swiped away to deep backward square. Only two.  CSK need two off the final ball
#
# yorker, just outside off, and slapped to deep point. Ball races to the fielder in the deep, and they complete an easy single. But wait.... Watson wants to come back on strike, and he's run out trying to complete the second run! Great throw from the deep, and terrific work from de Kock. New man in now with Chennai still needing four runs in two balls.  Dramatic!
#
# yorker, just outside leg, and hammered to wide long on. They come back for the second
#
# low full toss on middle, and drilled back to Malinga. He parries the ball to the leg side, and Jadeja scampers across for one
#
# yorker, on leg stump, from around the wicket. Toe-ends the drive to long on
#
# would you believe it?  Quinton de Kock has let the ball go for four byes! The South African has let this go through. Back of a length, on off, and QdK can't hold on despite Jadeja missing the cut. Oh dear.  CSK need 9 off the final over
#
# swung away to the leg side  but only to McClenaghan at deep midwicket
#
# length ball, just outside off, and Jadeja can't play the cut. Through to the keeper and Bumrah gives the batsman a wry smile
#
# full, just outside off, and he mistimes a slog to fine leg. They run hard, and comfortably complete the second
#
# given!  Back of a length on off again, and angling in. This ball, nearly 149kph, snakes off the pitch and takes the outside of Bravo's bat as he tries to loft it over cover. QdK ain't missing that, and Ravindra Jadeja walks in at No. 7
#
# back of a length on middle, and pulled to Krunal at deep midwicket. Watson goes off strike
#
# overpitched just outside off, and the slap has been stopped by Kishan at point! Crucial diving stop. That had four written all over it
#
# full, fast, and wide outside off. Left alone by Watson, and not a wide
#
# into the second tier!  Full, on middle, and Watson goes down on one knee again before clobbering a leg-side slog over deep midwicket. Watson hurting Mumbai after three dropped chances
#
# over Krunal's head this time!  Back of a length on off, and Watson rocks back before lifting a back-foot punch into the sightscreen. Simply amazing. Class is permament, folks
#
# hammered!  Full, too wide outside off, and Watson goes down on one knee before clearing a lofted shot over extra cover. There were two boundary-riders on the off side, but neither had any chance
#
# yorker, at the base of leg stump, and Bravo makes room before driving to deep extra cover
#
# length ball, just outside off, and fended off the back foot to cover. Just one.  CSK need 38 off 18
#
# wiiiild!  Back of a length on middle, and soaring over Watson. QdK dives to his left to try and stop the ball, but the ball flies off his glove. An extra run for CSK
#
# hits Watson near the gut!  Back of a length on middle, and angling into Watson again. He misses the pull, and the ball rolls away after hitting his body. Bravo wants a single, but he's been asked to go back. The direct hit from point doesn't bother umpire Ian Gould. Doesn't even go to the TV umpire
#
# fast!  Back of a length, on off, and the ball whizzes past Watson's bat. Misses the attempted cut
#
# once again, back of a length on middle and angling into DJ's body. Worked away to the leg side, rather uncomfortably
#
# back of a length, angling into Watson, and he's pulled this right in the air. Rahul Chahar gets under it from deep midwicket, and settles under it to take a catch, but my oh my, Chahar has  dropped this!
#
# yorker, around the wicket, and tapped away to point for one.  Watson keeps strike
#
# hello, rocket man!  What power, what timing. Another full one outside off, and Watson goes deep into his crease before hammering a shot through the covers. Nobody bothered moving
#
# slapped  over short third man, and deep point can't intercept either! Too full, too wide, and Watson has muscled a sliced shot behind square
#
# thick edge  between short third man and the keeper! Full on off, and his attempted drive finds enough contact to go behind him for four. Watson won't mind
#
# another low full toss, but this is mistimed down to long on
#
# bottom hand for the win!  Full, on his toes, and  flicked square  over cow corner! What a start to the over. Misses the yorker, and pays the price
#
# makes room and forces this slower length ball to deep point.
#
# banged in short, just outside leg. Watson ducks in anticipation of a wide but this is a good call from Ian Gould.
#
# slashes this as he gets onto the toes, down to square third man but it's a weak throw from Bumrah as they get back for the second
#
# beauty! It's the off-cutter angled across, Bravo looks to open the bat face to ease but is beaten
#
# punches straight to point, pressure building.
#
# hops across and defends this short of length delivery
#
# punches straight to extra cover. End of an outstanding spell. 4-0-14-1. Time for a breather as they take the time-out
#
# put down!   This was drilled straight back to the bowler, bobbled out of Chahar's hand on the followthrough.
#
# squared up by sharp turn, gets a thick outside edge to short third man as they scamper a single
#
# skids one on middle, Watson gets besides the line as he defends for a quick single
#
# wrong'un which he eases wide of point
#
# draws him forward in flight, Bravo defends
#
# slower delivery outside off, Watson picks out short third man as he tries to steer it wider. Doesn't have the pace to work with again
#
# bunts this to short third man
#
# has Dhoni been dismissed here stealing a second for the overthrow? Yes, yes. He is. Or is he? One angle says there's some doubt. Another suggests he's an inch short with the direct hit. In the end, he has been given. Dhoni started walking off even before the third umpire pressed the button. Then he stopped. Huge, huge moment in the match. Back to the ball: this was bunted to short fine as Malinga fired a throw at the bowler's end. They chanced a second because the mid-off fielder Ishan Kishan was a touch wide, but in thinking so, they may have been a tad too casual. Kishan moves to his left and hits direct at the bowler's end. Dhoni may have lost a split-second because he had to run around the bowler to get back into the crease. What a moment in the game.
#
# cuts this slower ball straight to backward point
#
# bowls his too far wide outside off, and it's been called rightly so by the umpire as Watson let that go
#
# chops this slower delivery to backward point. Pressure building.
#
# punched into the deep cover region
#
# sliding down and Watson sweeps, through Bumrah's legs to the boundary. Was placed specifically at short fine for the sweep. The bowler isn't amused.
#
# steps out and laces this wide of cover to get off the mark,  off his seventh delivery
#
# goes right back and bunts this to cover
#
# steps out and works this full delivery straight to short midwicket
#
# draws Dhoni forward and then gets it to beat the edge as he prods forward. Lovely from Rahul Chahar
#
# eased down to long-on
#
# copy book forward defence to a full delivery. Superb over
#
# leaves a skiddy length ball outside off, zips through to the keeper
#
# starts off with a jaffa! Angles in and holds its line as Dhoni pokes and misses
#
# has he got him? Yes, Rayudu walks. Ripper of a bouncer from Bumrah, Rayudu walks across to help this along but is beaten for pace as this flicks the glove on the way through to de Kock. Massive moment in the game. MS Dhoni will once again have to do all the heavy lifting to see CSK home.
#
# hops back and angles this down to third man
#
# slants in a skiddy length ball from wide of the crease, defended back
#
# fullish, wide outside off, and he attempts to cut this late. Finds the fielder at point
#
# teasing delivery full outside off. Rayudu steps forward to defend but the ball whizzes past his outside edge
#
# length ball outside off, and turning further away. Cut to deep point
#
# googly, length ball outside off and spinning inwards. Pulled to deep midwicket
#
# Chahar celebrates even before the umpire raised his finger!  Another skidder, length on middle and going straight through. Raina goes onto the back foot to defend, but he misses, and it hits his front leg. But Raina  chooses to review  after a long deliberation with Watson. Pitched on middle, impact on middle, and the ball would clip middle stump. Raina falls as Chahar drags Mumbai back into this game! Oh, and CSK lose their review as well. Ay Caramba.
#
# length ball on middle, and spins sharply into Raina. He tries to fend, but the ball has sneaked through to QdK behind the stumps
#
# length ball on middle, and he tries to play a delicate late cut. Played to short third man
#
# another slower ball, short and slow on middle. Mistimes a pull
#
# top-edged  and Malinga drops the catch. Is this Watson's night? Length ball on middle, and Watson was through his pull too early. In the air for a long time, but Malinga - at square leg - cannot cover the ground. Attempts a valiant dive, but the ball didn't even get his fingertips. Yikes
#
# slower ball, full outside off, and Watson drags a slogged shot to deep midwicket. No real timing there, but that's what allows him to come back for the second run
#
# slower ball, full outside off, and goes through to the keeper. Umpire Gould calls it a wide, but replays suggest the ball was inside the tram-lines. Touch and go
#
# hammered!  Full, on off stump, and Watson's fast hands makes no mistake. Demolishes this half-volley past the non-striker to the long-off boundary
#
# appeal for lbw  again with the slower ball dipping in late. Raina flicked this to fine leg, but McClenaghan believes it went off the pads. Nah, they aren't reviewing. It definitely came off the bat
#
# full on leg stump, and worked off his hips to deep midwicket. Tidy over, just the three runs
#
# full on off, and the  googly  goes away from Raina. Steered to short third man
#
# length ball on middle and turning into Raina. Tapped back to Chahar on this occasion
#
# length ball outside off and turning further away. Cut off the back foot to the fielder in the deep once again
#
# length ball on off and pulled off the back foot to deep midwicket
#
# length ball on leg stump, and nudged off his hips to square leg. Comfortably played
#
# fullish, on middle, and he mistimes a leg-side clip. Inside-edged onto his pads. An entertaining over comes to a close
#
# full on leg stump, and he misses the flick off this slower ball. Hits his pad, and Mitch appeals for lbw, but not given. Replays suggest it pitched outside leg
#
# length ball on middle, and nudged off his pads to fine leg for a single
#
# short ball , back of a length on middle, and the ball takes some extra bounce off the deck! Raina uncomfortably tries to defend, and the ball flies over his gloves and into de Kock's hands. Bowler appeals for caught-behind, and the umpire says out!  Raina reviews  straightaway. Replays suggest that Raina was right! No spike as the ball passes his glove. Looks like the decision has to be overturned, but before that the umpire wants to be sure he's got this right. Yep, not out! Umpire Gould changes his decision to 'one bouncer for the over'
#
# length ball o middle, and going down the leg side on this occasion. Wide called by the umpired
#
# back of a length, offcutter on middle, and defended off the back foot to the off side
#
# length ball on middle. Angling into his pads, and worked off his pads to the leg side
#
# length ball, on middle, and nudged off his pads to the leg side.  Timeout
#
# back of a length, just outside off, and cut behind square past the fielder at point! Allowing Watson to free his arms, and he doesn't disappoint
#
# back of a length on off, and Watson tries to pull but misses. Ball flies over his head to the keeper. Watson's not happy, he says a few things we can't repeat and the umpire calls it a wide. Ian Bishop apologises on TV for Watson's language. Think Watson wasn't happy with a wide not given in the Bumrah over
#
# swiped!  Full, on leg stump, and Watson simply flicks this over backward square for half-a-dozen. Watto spotted that slower ball (120kph) super early
#
# length ball, just outside off, and cut off the back foot to point
#
# sliced  but just past Chahar at point! Solid, diving effort, but the drive still had enough behind that shot to run to the boundary
#
# back of a length, just outside off, and fended off the back foot
#
# hops back and across to keep out this full delivery. Tight first over from Bumrah
#
# whips this over short square as he walks across.  Ishan Kishan was standing right where the ball went  and was moved out only a ball earlier to leg gully
#
# once again opens the bat face to ease this down to third man
#
# glances this fine to fine leg to get off the mark
#
# this is a snorter of a bouncer from Bumrah! Good evening, Mr Raina. He's as usual camping back, expecting this on his ribs and somehow sways out of the way. Terrific gather one handed by de Kock
#
# skids one through on off, steered to third man
#
# this time he's gone! Krunal sees him back away and fires this full and wide. Faf is so far off that he can't reach the ball and de Kock effects an excellent stumping. Rohit is pumped, Krunal is pumped. There's life in the game or what?
#
# backs away and cuts, straight to short third man this time. Deceived in flight but went through with the stroke
#
# makes room to open up the off side and slices this between cover and point. Wow, incredible batting this. The decision to follow him by firing it in isn't working for Krunal.
#
# clean strike, clears long-on! Backed away again, but Krunal went full and this was right into his swinging arc. Lovely, lovely hit.
#
# steps out and thumps this over the bowler's head, no chance for mid-on. Watson had to duck for cover as this was drilled!
#
# makes room, Krunal follows him, bunted to cover as he's cramped for room
#
# another risky run, this time they'll get four more because there's no one backing up. Faf had to put in a dive to beat De Kock's throw from behind the stumps. No one covering that from mid-on. This was another slower ball from Malinga, bunted behind the stumps. Even before Faf looked up, Watto was off, so he had no option but to go. It's all happening!
#
# a direct hit at the bowler's end from point and Watson would've been walking back!  This was a gentle bunt, waste of a run, loaded with so much risk. Ishan Kishan the fielder. Lucky break for Chennai Super Kings again
#
# beaten again! Backed away to pick the gap behind point, deceived by the slower one. Pressure building.
#
# slower and fuller on off, Watson's feet glued to the crease as he defends
#
# bouncer on middle, Watson hops back to keep that out
#
# length outside off, punched to sweeper cover for an easy single
#
# nicely held back, Watson gets a long way forward and defends
#
# goes right back and across as he defends this flatter delivery back
#
# too full and Watson gets to the pitch and thumps this through extra cover
#
# bunts this with the spin to short third man
#
# crunched from the crease but hit straight to point
#
#  just eludes Krunal on the followthrough!   Stopped on Faf, who looked to work it to the leg side. Got a leading edge, finger-tips stuff. Lucky break
#
# pulled nicely but there's a man strategically placed in front of square - between deep square and deep midwicket - for the shot. Two it will be to round off the first over.
#
# bunted to point from the crease, this was bowled full and across again
#
# full on the pads, flicked to Malinga at deep backward square leg
#
# blitzed! Too full, a half-volley that Faf will put away 99% of the times. Crunched through extra cover. Couldn't have asked for an easier ball for his first runs
#
# beaten as he looks to flay this on the up through cover. Lovely delivery, done in by the zip.
#
# driven back to mid-on. Hint of late inward movement for Mitch
#
# slower ball, full outside off, and  that's been smoked!  Drilled through the covers and  Chennai Super Kings 150 to win IPL 2019!
#
# full, wide outside off, and this time Pollard manages to free his arms.  Smashes  a four through the covers, and even manages to pierce the gap between deep extra cover and long off
#
# yorker, just outside off, and drilled to long off. They need to go for two, and McClenaghan is running to the danger end, but he can't make it back in time. Good news for Mumbai is that Pollard is back on strike
#
# yorker, but very wide outside off. Pollard lets the ball go despite not moving across, but  Umpire Nitin Menon says that's a fair ball!  Pollard throws his bat in the air, since he can't believe it
#
# through to the keeper!  Full, slower from Bravo, but wide outside the tramlines. But since Pollard walked across to the ball, umpire Nitin Menon deems that a legal ball
#
# full, very wide outside off, and  hammered  past cover to wide long off. Rayudu goes around the boundary to stop the ball, but  Pollard opts not to run!  They could've taken two, but Pollard was never interested. McClenaghan did try to run though
#
# delightful!  Slower ball, short on middle and teasingly over Mitch's bat as he tries to swing to the leg side. Great comeback for Deepak Chahar tonight after getting tonked by de Kock earlier in the evening
#
# length ball, wide outside off, and Mitch pulls off the back foot to midwicket
#
# full on middle, and his attempted slog over cover is sliced only to mid off. Pollard hasn't crossed over either
#
# length ball on middle, and worked away to the leg side
#
# yorker on middle, and Hardik can't flick it square. Ball hits his front leg, and Chahar appeals for lbw.  Ian Gould raises the finger but Hardik reviews right away!  Bat involved? Looks like the bat did not hit the ball, it only hit the ground. No edge according to UltraEdge so far, and replays show that ball would've crashed into leg stump. Big wicket for Chennai.
#
# back of a length, wide outside off, and   Pandya flat-bats a pull  through to the wide long-on boundary! Chahar tries for the slower short ball, but Hardik was up for the challenge. What timing!
#
# low full toss, very wide outside off, and thumped to long on for a single. Hardik keeps strike
#
# helicopter shot  with Dhoni looking on! The audacity! Love it. Full, on off, and Hardik stays really deep in his crease before letting his bottom-hand do the rest. The crowd roars!
#
# attempted yorker, but ends up as a low full toss. Drills a drive to long on
#
# rubbing salt in Shardul's wounds!  Back of a length on off, and Pollard rocks back deep before punishing Shardul for a six. Thumps a pull over cow corner
#
# up and over  off the back foot, and Raina is getting under it from cover, but  he's dropped it!   Chinna Thala  fails to hold on. How rare is that? This was a short ball from Shardul, and Hardik tried to lift it over cover, but alas
#
# full, on off, and driven down the ground to long on. Gives Hardik the strike
#
# length ball outside off again, and he pulls once more off the back foot. No real timing this time. Through to the fielder at cow corner
#
# going, going, gone!  Half-tracker from Tahir, sliding into leg stump and Pollard rocks back before pulling this over backward square. Massive
#
# full on off, and  turning away  after hitting the deck. Tapped off the front foot to cover for a quick run
#
# yorker  on off, and Pandya does well to dig this away. Bunted back to Tahir
#
# slider, length ball outside off and zipping through. Tries to flat-bat this over long on, but doesn't find the connection. On the bounce to the fielder in the deep
#
# half-tracker, just outside off, and he offers the bat's full face to play this down to long on
#
# faster one again. Length ball angling into his body, and drilled to long on once more
#
# length ball, wide outside off. Punched back to long on
#
# hammered  over cover, but lands just short of the Chahar in the deep! Terrific commitment from Chahar to attack the ball, but the ball drops just in front of his dive and bounces away to the boundary. This was a fast ball outside off and Pollard slapped it over the infield
#
# wide, length outside off, and cut of the back foot to the man in the deep. Just a single for Pandya
#
# full on middle, and he takes a big stride forward to block. Ball rolls back to Jadeja
#
# around the wicket, length ball outside off, and thumped off the back foot to long on
#
# skids one through on middle and leg, punches to deep midwicket
#
# lunges forward and defends
#
# backs away to hoick, top-edges the slog and point takes a dolly. Imran Tahir is off again. This is very poor application from Kishan. Looked edgy all evening and has succumbed to the man who has dismissed him four times in four matches earlier to this.
#
# works this down to long-on
#
# fired full to hit him on the pad as he looks to work it to the leg side
#
# goes straight and clobbers this into the sightscreen. There was a straightish long-on in place for precisely such a shot but he was happy to take him on. What muscle
#
# flatter one on middle and leg, he works this wide of midwicket for an easy single
#
# whips this down to long-on again
#
# tucks this gently into the leg side for a quick single
#
# eases this down to long-on
#
# skids through to beat Kishan's edge as he looks to late cut
#
# sharp turn from length outside off, Kishan defends
#
# superb short ball again, just outside off, Pollard gets out of the way.
#
# excellent short ball, rising in towards the body, Pollard hit on the ribcage as he walks down the pitch to meet it
#
# rolls off the pad to square leg as they scamper a leg bye
#
# beats him for pace and takes an excellent return catch as he hares across to grab it! Shardul, you beauty. Krunal, like de Kock, is beaten for pace as he looks to pull this skiddy delivery but gets it high on the bat. Lobs so high that Shardul has enough time to cover at least 20 yards but in trying to grab it the ball bobbles out. Somehow he still manages to retain his composure and take it on the second attempt. Heroic from Shardul as he tumbles over. What. A. Catch. No repeat of Krunal's heroics at the same venue where he delivered Mumbai the title in 2017.
#
# driven on the up into the gap at sweeper cover, Chahar cuts this off as he comes around
#
# punched uppishly into the gap behind point
#
# gentle dab into the gap at point for an easy single
#
# nicely tossed up, Krunal is well forward as he smothers this
#
# skids one across, Krunal plays this delicately past slip. Bravo gives it a good chase from short third man to pull it back in
#
# lunges forward and turns this gently into the leg side
#
# chopped on and Imran beings his victory run! The length does Surya in, looking to dab this past short third man but is cramped for room. Thick inside edge back onto the stumps. There wasn't much turn this time.   Tahir equals Rabada for most scalps this season - 25
#
# works this off a length into the gap at wide long-on. Lazy work in the deep. Should've been no more than a single.
#
# picks this full toss into the gap at wide long-on and deep midwicket. Lovely wrist work from Ishan
#
# fired full outside off, squeezes this to deep point
#
# pushes this length ball to short midwicket
#
# goes through with the shot and just eludes Jadeja at deep midwicket. magnificent effort. Gets away with the release shot does Surya. Didn't get to the pitch of this tossed up delivery but went through with that whip. Top, top effort from Jaddu, running around the ropes.
#
# brings out the switch hit but toe-ends this to point, they squeeze in a single
#
# sharp turn off a length, bunted to point
#
# full, on off and angling away. Muscled to long off for a walking single
#
# slower ball, but it's a full toss on leg stump, and Kishan swats this away behind square! Adjusts well to meet this ball late, and slog sweeps this for four
#
# full on off, and he walks across to the off side before driving down the ground. Mid-on intercepts
#
# back of a length, just outside off, and he goes onto the back foot to block. Ball rolls back to DJ
#
# through his shot early  but nobody's there at mid-off. Length ball on middle, and Kishan mistimes his drive. Through to long on
#
# back of a length, just outside leg stump, and soars over Kishan's head. MSD does well to jump and stop the ball with one hand
#
# welcomed with a four!  Full, on Kishan's toes, and he clears his front leg before hammering a shot over mid on
#
# fuller, on middle, and thumped down the ground to long on for a single.  Timeout
#
# length ball, wide outside off, and cut away to point
#
# back of a length, just outside off, and punched off the back foot to long on. They walk across for one
#
# length ball, just outside off, and slapped away to deep extra cover for a single
#
# back of a length, just outside off, and he tries to punch. Spliced to Raina at cover, ball lands just in front
#
# length ball very wide outside off, and turning further away. Kishan stretches forward before letting it go
#
# swept  but only to the fielder at deep midwicket. Full on off, and Suryakumar goes across the line to try and meet the ball
#
# length ball, hard Test-match length. Lands on middle, and meets Kishan near his chest. Tapped back off the back foot
#
# length ball on middle, and defended off the back foot to point. Protection there
#
# full on leg, and he offers the bat's straight face to drive down the ground. Long on runs to his left to clean up
#
# length ball, angling away from Kishan. He opens the bat's face and steers it down to third man
#
# chipped  but lands in no man's land. Fullish on leg, and Suryakumar's attempted flick takes a leading edge towards mid on
#
# slower ball, offcutter to begin proceedings. Length ball, just outside off, and Suryakumar mistimes a front-foot drive to mid-off
#
# quicker one to end the over. Lands on off and skids into his pads. Worked away behind square off the back foot
#
# length ball outside off, and nudged away with the offspin to midwicket
#
# length ball, on off, and punched past the non-striker to long on. Played off the back foot this time
#
# length ball just outside off, and turning in. He goes deep inside his crease to block
#
# full, on off, and defended towards the off side. They scamper across for one after a bit of hesitation
#
# full on off, and turning into his body. Nudged off his pads to square leg for a walking single
#
# sneaks past the outside edge!  Length ball, just outside off, and angling away slightly. Kishan tentatively presses forward, but he can't get the connection
#
# inside edge  onto his pads. Fullish on off, and Kishan presses forward to defend. Takes the inside-half of his bat and hits him near the gut
#
# full on off, and he check-drives towards the off side. Stopped by the fielder at cover running to his left
#
# length ball on off, and angling further away. Left alone by the new batsman
#
# slower ball, and edged!  MSD dives forward to complete the catch. Knuckleball just outside off, and Rohit tries to drive straight, but he's through his shot too early and Dhoni was not going to make any mistake. Terrific delivery from Chahar
#
# overpitched, on off, and struck straight back to the bowler. He bends to intercept on his followthrough
#
# nice and full outside off, defended back
#
# excellent comeback! Shardul has his revenge this time and he's done him in with a real quick delivery. Bounced on middle to cramp him for room, de Kock late on this, gets it on the glove and lobs behind to Dhoni who takes a dolly. Shardul gives de Kock a send-off and Hyderabad roars.
#
# slapped! This is gully cricket style. Fab shot. Saw him drop shot, reached out and was on one leg as he hammered this in front of square. Disdainfully done
#
# beaten as he bowls this full and wide as De Kock makes room to scythe that behind point
#
# no point of that fielder if Shardul's going to bang it in. Pulled again  but Rohit gets this high on the bat, on the bounce to Harbhajan at deep square leg
#
# helped along one bounce to Tahir at fine leg
#
# swept well, beats short fine! Harbhajan fired this on middle and leg, picked beautifully by Rohit.
#
# steps out but Harbhajan cleverly shortens his length, punched back by Rohit
#
# yorker-length, squeezed back
#
# steps out to hoick across the line, gets a thick inside edge to square leg
#
# shortish and spinning into middle and leg, punched to wide mid-on. de Kock turned for the second and had taken five steps in when he turned back.   De Kock turned blindly, didn't hear Rohit's call of 'no'
#
# driven with the spin to long-off
#
# slashes hard to Harbhajan on the bounce at third man
#
# scorcher! Length ball slanted across, de Kock makes room and lofts through the line over mid-off. Pure hand-eye coordination this. Timing is incredible too
#
# wrists this full delivery on middle and leg to mid-on
#
# sliced for six! Backs away to go extra cover but doesn't quite get the timing or bat. Went off the thick outside edge. For a split-second, Harbhajan looked set to lap it up at square third man but watched this sail over in the end. Woah, how did that carry? I really don't know.
#
# punches this length delivery to cover
#
# the consequence of that six is Chahar goes wider and ends up toeing the wide line. De Kock cleverly let that go. Extra ball, the bowler is under pressure early in the over
#
# smoked! This is floated full and across, de Kock walks across and whips this over midwicket. Strong bottomhands, sailed over. Super hit, mind you it's a 73-metre square boundary. No problem, I'll hit it over and beyond.
#
# caresses this full delivery to Raina at cover point
#
# that's what he can do often, does Shardul. Bowl beauties and then follow it up with half-trackers. Drops short and into the body, Rohit was waiting for it. Pulled imperiously over deep square. Super hit, so instinctive, very very effective.
#
# nice and full on the stumps, gets this to move away late again, Rohit jams his bat down in time to squeeze this to mid-on
#
# beauty! When he gets it right, Shardul can get the ball to bend away. Banana swing this time, Rohit with no feet movement as he throws his bat at this to drive, beaten.
#
# mistimes a cut to cover point. Cramped for room again
#
# length ball on middle and leg, Rohit works this into the gap at midwicket
#
# beaten by zip and extra bounce. Not much of pace or so to say, just 129.2kph, looks to flay that through point but is late on the shot.
#
#  nearly drags it onto the stumps!   Looks to thump this on the up through extra cover but didn't have room. The thick inside edge rolled onto the pad and nearly to the leg stump. Just wide. Slice of luck for Mumbai early in the piece
#
# lucky to get away with this!  Too short and wide outside off, de Kock reaches out and slaps this straight to cover point
#
# pitched up and de Kock drives but straight to extra cover
#
# short of length on middle and leg, nudged into the leg side for a quick single
#
# slants a short ball across, de Kock cuts and gets a thick bottom edge to Harbhajan at square third man
#
# there it is, CSK are through to their eighth IPL final. Another bouncer, angling into the left ribcage. Steps across and fends at it, gets just enough on it to beat Pant throwing himself to his left behind the wicket
#
# short, gets up to chest height on off stump, pulled through midwicket, along the ground
#
# short outside off, and Dhoni's pulled it straight to the man on the boundary! Keemo Paul hardly had to move there, at deep square leg. CSK will have to wait just a little longer
#
# back of a length on off stump, punched to extra-cover
#
# down the track and Ishant tries to cramp him by bowling it full at his feet. Ends up as a low full-toss and Dhoni chips it back over the bowler's head. Munro does well to field it, running hard to his left at the long-on boundary
#
# back of a length in the corridor, nips away off the seam, Dhoni jabs at it without any footwork and the ball beats his outside edge. Ishant's bowled a lot of this sort of ball in Test cricket of late
#
# length ball close to off stump, presses forward and pushes towards backward point
#
# short, wide, Rayudu gets on his toes and slaps it away to the backward point boundary
#
# slower short ball, jags in off the pitch from outside off. Rayudu is through his pull too early and the ball grazes his glove and hits his stomach
#
# bouncer outside off, Rayudu thinks of hooking, and in the end decides to drop his bat out of the way and evade it
#
# back of a length, angling down leg, and you can't keep bowling that line. Rayudu tickles it away nice and fine, and fine leg is once again too fine to be able to stop this
#
# full, angling into the pads, clipped to fine leg
#
# on the fuller side of a good length on middle and leg, blocked back to the bowler
#
# digs it in short, gets it up near Dhoni's right collarbone. Rolls his wrists over to pull along the ground to fine leg
#
# full on middle and leg, clipped to the left of fine leg
#
# short, down the leg side, and Dhoni helps it off his hip to the fine leg boundary. Fine leg was way too square to even think of stopping this
#
# very full, sixth-stump line, Dhoni doesn't really move his feet. Jabs at it and gets a thick inside-edge that pretty much doesn't go anywhere
#
# back of a length, angling across the stumps. Stays leg-side of the ball and jabs to deep point
#
# bowled him. There's already been one thick inside-edge in this over, and now he drags one onto his stumps. This was perhaps a touch too close to cut, and he goes at it with an angled bat and chops it on
#
# flatter, on the pads, clipped through square leg
#
# shot. Down the track, moving away from leg stump, and he gets into the perfect spot against this flighted ball to loft it inside-out over extra-cover
#
# flat, back of a length outside off, waits on it and chops it through backward point
#
# down the track and Axar angles bowls it flatter and shorter outside off. Looks for the leg-side heave and drags an inside-edge past leg stump and the keeper
#
# flat length ball wide of off stump. Raina goes for the hard sweep and misses
#
# very full on off stump, jabbed down to long-on
#
# flat legbreak on leg stump, swept along the ground to deep backward square leg
#
# flatter and fuller, blocked back to the bowler
#
# nicely looped up on middle stump. Doesn't get to the pitch with his front-foot stride. Wanted to drive to long-off, has to instead adjust and dab to backward point with an open face
#
# slow legbreak outside off, waits on it and punches to the off-side sweeper
#
# front-of-the-hand delivery, ends up dragging it short, pulled firmly and on the bounce to deep midwicket
#
# flat length ball outside off, blocked back to the bowler
#
# full on off stump, driven to long-off
#
# flat, fairly full, speared in towards leg stump. Looks to work it leg side but it grips and turns and rolls off the leading edge to backward point
#
# tossed up on off stump, clipped to long-on
#
# length ball outside off, driven to deep extra-cover
#
# full on off stump, worked with the turn through square leg
#
# tossed up outside off, driven to long-off
#
# flat on the legs, worked through square leg
#
# length ball outside off, pushed back to the bowler
#
# ooh, could easily have been a caught-and-bowled. Shortish googly spinning down leg. He picked the wrong'un, but it stuck on the pitch and popped up off the leading edge as he looked to work it into the leg side. Didn't pop back to the bowler, though, just a short distance towards extra-cover
#
# down the track comes Watson, and this time he's found the fielder. Mishra straightened his line, bowled it at middle and leg to cramp Watson slightly, and his lofted inside-out drive doesn't carry as far as he wanted
#
# full outside off, driven to long-off
#
# slower ball, full on off stump, and Watson miscues it for six to bring up his fifty. A little unfair on bowlers, this game can be. Watson went for the big hit over long-on, I think, and he ended up slicing underneath the ball and sending it hiiiiigh over long-off, but he's also managed to put enough into the shot for it to carry all the way
#
# looks for the leg-stump yorker, ends up sliding down the leg side and forcing Pant into a diving save
#
# slower length ball wide of off stump, and Watson gets a big stride out and fetches a slog-sweep all the way over the wide long-on boundary
#
# short, shoulder-high ball outside off, plays a checked pull along the ground to long-on
#
# slower length ball on off stump, clipped down to long-on
#
# short again, this time it sits up outside off and Watson pulls it over midwicket, into the wide open spaces at that boundary
#
# shortish, angling down leg, and Watson just dismisses it from his presence, a whip off his hips that carries all the way over the backward square leg boundary
#
# length ball on middle stump, stays leg-side of the ball and opens his bat face to steer it to third man, past the diving backward point fielder
#
# in the blockhole on leg stump, jabbed back towards the bowler
#
# back of a length on the stumps, doesn't give Watson the width he was looking for while stepping away from leg stump. Dabbed towards backward point
#
# full, angling into the stumps, clipped through square leg
#
# short on leg stump, and there's the breakthrough. Was a little cramped for room while looking to pull this, and he can't quite get the power on it to clear the boundary. Keemo Paul catches it diving to his right at deep square leg
#
# length ball close to off stump, slapped to short extra
#
# nudged to point, but straight at the fielder
#
# slammed into the stands!  Axar spears another one in at the pads, but Watson meets it with a huge slog sweep and connects well
#
# another paddle-sweep from Watson, and though there's a hint of top edge about this one, there's no-one at short fine leg
#
# eased down to long on, and that's  fifty for Faf!  His 12th in the IPL
#
# chopped down towards point this time, but again they can't find a run
#
# Axar darts one in at the stumps, Faf nudges to cover, but he can't find space for a single
#
# Faf flicks off his toes, and the fielder is in quickly enough from long on to keep them to one
#
# slashed uppishly and out to wide long off, where it's Munro again who cuts it off
#
# punched to cover point, no run
#
# Mishra to du Plessis, 1 run
#
# Watson slog, skies and the ball goes almost straight up! But who wants it? Prithvi Shaw is close in , but it's Munro who runs in from long on ... and he can't get to it in time! Really, that was Prithvi's catch. Munro had so much ground to make up, Prithvi was right there
#
# lapped down to fine leg! The boundary down there was left open, and Watson bent low to fetch this from off stump and paddle it very fine
#
# this one keeps low!  Faf lunged down at it as the ball crept through low, and just about got the bat there in time, bottom edging it past short third man. Munro hares after it, and slides into a dive at the boundary, parrying it back in. But is his foot in contact with the boundary as he does so? The TV umpire Shamshuddin checks out several replays and eventually decides that it's a boundary - and possibly a vital one. It was a very close call, and a tough one
#
# Paul finds some cut in to Watson off the track, but the ball is dead-batted into space on the off side and they sprint through for a single
#
# helped on its way!  Paul bends his back to send this down at 138km/h, but it's a full toss outside leg and Watson just needs to put bat to ball to get his first boundary
#
# slower one, right down to 102km/h, and Faf waits to flick into the leg side
#
# a late dab brings a single to third man
#
# oh dear, the full pace delivery at 135km/h is sprayed down the leg side, evading a diving Rishabh Pant and racing away for five wides to  bring up the fifty stand
#
# and he starts with a slow yorker, delivered at just 110km/h but right on target and aimed at Watto's toes
#
# swept fiercely!  Faf has well and truly got his eye in now, and he bends low to get himself in the perfect position to swat a sweep out to deep square
#
# Watson lunges out at a full one, outside off, and drives to long off. He made sure to get forward
#
# slightly quicker at 84km/h, and it looked like a googly too, but it's read and driven to long off
#
# Faf puts a little more vim in this drive, but he can't beat the cover ring
#
# wonderfully flighted outside off by Mishra, the ball arriving at 75km/h as Faf taps to point
#
# leggie, floated up on leg stump, and Faf is forward to push to mid on
#
# Faf is a little early into this forcing stroke as the ball seems to hold up a little, but the ball rolls into a gap on the leg side and they take a single
#
# Ishant aims a full one for Watto's pads, a single into the leg side the result
#
# shorter this time, and Faf rides the bounce to tuck a single square on the leg side
#
# three in a row!  Length isn't working for Ishant. Faf waits deep, and it's  just  short enough that he can muscle a pull out to deep midwicket
#
# past a diving short third man!  Faf knew Ishant would correct his line, and makes room to attack the off side. He doesn't keep the shot down, though, and it's not far away from the diving fielder inside the ring. Once past him, it's four
#
# whipped behind square! Faf is reading the length very quickly tonight, and now he's also gifted a helpful angle by Ishant, helping the ball on its way down the leg side
#
# Watson cuts again, and hits it better this time, but straight at the point fielder
#
# Watson now looks to make room, but the ball rushes on to him, cramping a cut that goes nowhere
#
# good follow-up, Faf turning the strike over with a single
#
# moosed over extra!  This is masterful from Faf, who backs away and powers the ball up and over the cover boundary
#
# slapped up and over extra cover! Faf favours that area, and once again he makes room to set the shot up
#
# Faf backs away, giving himself acres of room, but slices under the ball and very nearly spoons a catch to short third man, who stops it on the bounce
#
# Faf and Watto are doing this in singles, as a shot comes off the toe end, trickling to mid on
#
# nudged softly into the leg side, and there's room for a single
#
# Watson waits and dabs late, but he can't beat short third man
#
# worked off the straight by Faf, who collects another single out to deep midwicket
#
# once again Faf is down the track, giving Ishant the charge, but he's undone by a change of pace, flinging his hands out way to early and missing the ball
#
# Faf walks out at the bowler, slamming a drive to mid off. This time he doesn't opt for a risky single
#
# Faf whips across his pads, collecting a single into the leg side
#
# Boult finds some lift outside off, Watson milking a single down to third man
#
# another tip-and-run single from Faf, tapping to mid off and setting off. He's certainly keeping Capitals on their toes
#
# slugged over the leg side!  Faf read the length on this early, and was ready and waiting in position when the ball arrived, pulling hard and in the air off the front foot
#
# angled down behind point, just the one
#
# another brave run! Faf pings mid off perfectly with his drive, but he was always going to run and he's quick enough to have his bat grounded inside the line by the time the shy swerves past the stumps. It was Shreyas with the throw
#
# Faf is forward, on the drive, and aims his shot straight at mid off - but this time he calls clearly and early, puts his head down and gets home safely - though the shy also goes wide
#
# Ishant hits a length on off stump, and Watto softens his hands to collect a quick single, close in on the off side
#
# slower cutter from Ishant, Faf nurdling it into the leg side. There's another moment of hesitation before they complete the single ...
#
# angled in, on a length, and Faf is content defending from the crease
#
# full, and Faf steps into a thundering drive, but the mid off fielder gets himself in front of it
#
# rising up outside off, Faf standing tall to meet the ball and punching to point, where an athletic stop saves the run. Capitals are buzzing in the field
#
# inside edge , and it might have saved Watson as he's struck on the thigh. At least, it stifled Boult's appeal for lbw
#
# Watto looks for a dab down to third man, but he can't beat gully
#
# full, tapped to mid on. No attempt at the run this time
#
# chaos!  What has gone out there? The ball was tapped to point and Faf set off, and then stopped. Watto, too, had started to run, stuttered, and now he turns back. The batsman meet mid-pitch in utter confusion! There are shies at both ends, but they both miss and - eventually - Faf gets down the other end for a single. Phew!
#
# big appeal!  Boult snakes a fuller one in to Faf's pads and belts out an appeal, but the umpire shakes his head. And there's no review. It pitched way outside leg
#
# Boult, as is his wont, is right on the mark first up, curving a length delivery in towards Faf's off stump, but the South African skipper responds with steely-eyed and solid defence
#
# wow, what a finish, and from who! Down the track once more, and this time he makes himself a bit of room as well. Jadeja pulls his length back, and Ishant flat-bats it, middles it, and easily clears the boundary to the right of long-off
#
# another great effort from Faf, but this time he can't stop it. Down the track jumps Ishant, and he gets close to the pitch and swats it hard and flat, back over the bowler's head, and Faf, throwing himself to his left on the long-on boundary, can't quite pull it back
#
# back of a length on the stumps, jabbed hard, back to the bowler
#
# similar line and length, but this time it's slower and slightly shorter. Boult swings too early, a little across it, and misses, and loses his leg stump
#
# whoa. Flat length ball on leg stump, and he clears his front leg and hoicks it high over long-on. That was powerful
#
# flat, angling into off stump, and Boult jabs it back to the bowler, at catching height. Miraculously, Jadeja drops it despite getting both hands to it
#
# another full one on off stump, and this time Mishra steps across and flicks it behind square, up and over to the left of short fine leg. What a shot!
#
# oh my, Faf du Plessis, what an effort that is! That's full, on the stumps, and Mishra flicks it - it's almost the helicopter shot - up in the air, times it extremely well towards the wide long-on boundary. Faf sprints at full tilt to his right, throws himself horizontally at the ball, and slaps it back into the field just as it's about to clear the boundary
#
# got him. Sticks to that line outside off, bowling the cutter into the pitch and making Pant fetch it against the angle. Goes for the big one this time, and can't get it far enough to the left of long-on
#
# the line was getting a little predictable, and he angles another back-of-a-length ball away from off stump. Pant reverse-swats it over backward point, but can't get too much power on it because it's another slower one. They run two even though he hit it close to the fielder at deep point, and Rayudu's throw misses the stumps with the batsman yards from making his ground
#
# back of a length now, digs this slower offcutter into the pitch, and angles it away from Pant's hitting arc. Again hits along the ground, and again into the gap between long-on and deep midwicket to pick up two more
#
# slower length ball angling away from off stump, hoicked along the ground between long-on and deep midwicket
#
# full on middle and leg, clipped to deep square leg. No single taken, and rightly so.
#
# boom. Perfect leg-stump yorker, at full pace - 139kph, which is super quick for Bravo - and Paul is sure as hell surprised. Big backlift, clears his front leg, prepared to hit over the leg side, and suddenly the ball is hurtling towards his toe at unexpected pace. Before can bring his bat down the ball is past him and his stumps are disturbed
#
# full outside off, too full to hit down the ground, driven to the left of deep point
#
# slower length ball angling away from off stump. Looks to get down on his back knee to slog-sweep, and ends up inside-edging past leg stump
#
# down the track and Bravo spears a full one away from his reach, outside off. Goes hard at it but can only hit it into the pitch and back to the bowler
#
# shortish slower one pitching outside leg. Steps across to try and pull, and he misses. Doesn't miss the glove by much and the umpire doesn't call wide
#
# goes for the leg-stump yorker, ends up bowling it down the leg side
#
# ...
#
# too full and given room outside off, stroked away nicely, but point is alert and intercepts
#
# turn again, from a length, spinning from leg to off. Rayudu stays back and whips it to midwicket
#
# fullish spinning into Raina from a widish angle, he plays with the turn towards square leg
#
# tossed up on middle and leg, he defends with a big stride forward. The ball rolls off a thick inside edge and they take a quick single
#
# strays on the pads, but Rayudu can't find the gap with his flick, only goes to square leg
#
# length on off, turns away, steered towards gully
#
# dropped by Umesh running in from the square leg boundary  five dots balls and Rayudu went for the slog-sweep, got a top edge that hung in the air. Umesh sprinted in and got there, but the ball popped out of his hands
#
# quicker, steered into the offisde
#
# good length outside off, turn again. Some tricks from AB, who parried the ball to Moeen even as he was sliding to stop it at mid-off
#
# gets some turn from outside off, Rayudu moves inside the line to tuck it to short fine leg
#
# defended into the offside
#
# length ball outside off, steered to Siraj at short third man. Raina had set off at the non-striker's end and had to scramble back. Saved because Siraj also couldn't pick it up cleanly
#
# on a length outside off, clipped to short midwicket
#
# tossed up nicely, draws him forward and he checks his drive. AB is there at short cover, but he slips and the ball goes past him
#
# drifts on leg again, clipped to square leg
#
# fired in and strays on leg, Raina turns it around the corner to short fine leg
#
# given some air, pitches outside off and spinning into Raina, who wants to defend with bat beside pad, but is hit on pad. Struck outside the line
#
# got him  that's an ugly heave from Watson to a slider that pitched on off. Went for a slog sweep but misses it entirely and the ball cannons into the stumps.
#
# takes the attack to the bowler, down the track to a short ball at 140 kph and he latches on to it, pulls it well. So well in fact that it carries over the long-on fence
#
# another one that's hurried him, 143 kph, coming in from middle, and he tucks it off his thigh pad
#
# rapped on the pads and half-hearted appeal. Nipping in from outside off, but too high
#
# pings him on the helmet  that's a snorter of a bouncer, rises up sharply and hits Watson on the front of the helmet, while he was trying ot pull. Too quickly onto him, on a pitch that's slow - that is impressive bowling
#
# back of a length, punched to deep cover
#
# back of a length, nipping in from outside off, defended into the offside
#
# googly that stops on the pitch, Watson drives it early, uppish but lands short of cover-point  starts with a maiden
#
# and beats him with the turn that time, draws a leading edge towards gully. Tossed up on leg, Watson wanted to flick
#
# quicker one, at 97 kph, fired into middle and leg, kept out by Watson
#
# ooh and there's turn there. Pitched on leg, and spun across, takes the shoulder of the bat and rolls away
#
# good length, slider that scooted through. Watson got his bat down in time to defend
#
# fullish on off, big stride out and driven to short cover
#
# and he strikes first ball. Parthiv it is, so he doesn't become the first batsman to carry his bat in the IPL. Coming to the ball, it was short down the leg side, Parthiv goes for the pull but ends up hitting it straight to Jadeja at square leg
#
# length outside off, comes forward to defend and gets beaten like so many others before him as the ball spins away
#
# Jadeja gets his line right finally, pitching on middle and spinning away, comes forward to defend and beats the bat to flatten the off stump
#
# fuller around off, comes forward and pushes it back
#
# turn and bounce from length outside off, defended from the back foot
#
# length around off, and beats the batsman with the turn as he looks to defend
#
# length outside off, goes for the sweep and misses, gets hit on the pads and gets a leg bye as the ball rolls towards short third man
#
# length ball outside off, Parthiv goes back and across and tucks it away towards square leg
#
# flighted around middle, comes on the front foot and drives it towards extra cover
#
# flatter around off, pushes and gets an inside edge towards square leg
#
# flighted outside off, Umesh looks to hit it away but gets beaten, Dhoni whips off the bails but Umesh's back foot was always grounded behind the line
#
# length ball around off, Umesh comes forward to defend and gets beaten by the turn
#
# fuller on the toes, clips it towards square leg for one
#
# misses the off stump by a whisker.  Length ball around off, Umesh lunges forward but gets beaten
#
# fuller on the stumps, drives it towards midwicket for one
#
# length ball outside off, looks to steer it fine, misses
#
# length ball on the stumps, swipes it behind square leg for a couple
#
# length ball on the stumps, looks to flick it on the leg side, misses. An appeal for lbw but denied. Jadeja was excited and Dhoni has decided to review it. Hits him near the knee roll. Pitched outside off, and spinning in to hit the batsman in front of middle but it was going over the stumps. CSK lose their review
#
# length ball around off stump, Parthiv waits for it come in with the angle before opening the face at the last moment to guide it past Dhoni
#
# flatter on the leg stump, pushed towards short midwicket from the front foot
#
# length outside off, comes forward to block but gets beaten as it spins big
#
# goes for the slog sweep, the idea was good as it was a googly but doesn't get the timing right and Harbhajan takes a neat catch pedalling backward at deep square leg
#
# falls short of diving Jadeja at backward point, Chahal comes forward to this tossed up delivery, doesn't get to the pitch and ends up slicing it towards point
#
# length on middle and leg, comes forward, wait for it to spin and dead-bats
#
# tossed up outside off, comes forward and drives it towards cover
#
# slog swept towards the vacant deep midwicket, length ball on the stumps, Chahal looks to go big but doesn't get the hold of it, comes back for the third
#
# length ball around off, goes back and punches it towards covers
#
# looks to heave it on the leg side, length ball outside off, makes no connection
#
# flatter on the stumps, fuller as well, Chahal defends it from the front foot
#
# fuller outside off, comes forward and sweeps it behind square
#
# length ball around off and spinning down the leg side to beat the batsman
#
# tossed up around off, comes forward and defends it back towards the bowler
#
# tossed up wide outside off, taken on the full. Driven towards long-off for one
#
# flatter one, in the line of the stumps, Chahal goes for the sweep and just manages to get his bat down
#
# flighted around off, comes forward and defends
#
# length outside off, goes back and cuts it towards backward point
#
# fuller around off, a googly again to beat the forward defence, an appeal for lbw but think it hit him outside the line of the off stump. Not out but Dhoni has decided to review it. Front foot is fine. Looks like there is some bat involved, an inside edge, replays confirm. But wait, Watson have taken the catch as well, so it's not lbw but caught behind
#
# fuller around off, comes forward and pushes, a thick outside edge behind point
#
# fuller around off, comes forward and flicks it behind square
#
# fuller around off, Saini comes forward to drive, a leading edge towards covers
#
# caught behind!  A similar delivery, but a touch fuller this time, pitching around off, de Grandhomme comes forward to defend but it spins away sharply to take the outside edge, Dhoni makes no mistake
#
# length around off, flatter and quicker, spins away from the batsman who looks to defend, beaten
#
# length outside off, comes forward and turns it towards short fine leg
#
# flatter one at 92kph, de Grandhomme was playing back but gets his bat down in time, an inside edge on to the shoe
#
# fuller on middle and leg and de Grandhomme just chips it over the leg side, beats the man at long-on and deep midwicket
#
# tossed up around off and middle, drives it towards covers
#
# another googly, length around off and middle, defended from the back foot
#
# Dube departs cheaply, googly does the trick. Was a length ball around off and spinning away, Dube looks to steer it on the off side, gets an outside edge and Watson takes an easy catch around stomach height at first slip
#
# starts with a flatter one around off, defended from the back foot towards extra cover
#
# fuller on off, takes a thick inside edge to midwicket
#
# length ball on off, he waits for it and pushes between cover and point
#
# tossed up, Parthiv takes it on the full off the front foot and flicks it nicely to deep midwicket
#
# fuller, pushed to long-on
#
# turn  Raina's getting to spin like Murali! Pitched on a length and spun sharply across Dube, who was flummoxed
#
# too short and he rocks back to pull this to long-on
#
# oh what have you done Shimron Hetmyer?  This was given some more air, Hetmyer came on the front foot and pushed to Raina at cover. For some unfathomable reason, he thought there was a run there and was halfway down the pitch. Raina reached the ball by then and flicked it to Dhoni. Hetmyer gave up the ghost and just stood there, watching the bails get whipped off.
#
# flatter, into leg stump, he moves back and slaps to mid-on
#
# strays on the pads and the ball rolls away very close towards backward square leg. RCB's thinking is so muddled they went for that run. Dhoni had run to field the ball and had he hit the stumps, Hetmyer would have been out. But he doesn't hit
#
# backs away and drives this fuller length ball to cover
#
# you cannot deny Harbhajan today  AB tries to sweep again, but doesn't get hold of it once again. The pitch is not one where you can rely on the ball coming on even a bit, and AB is too early, the top edge flies to midwicket this time. And Jadeja is the man there, he isn't going to drop any. even when he has to run in and dive forward. RCB in tatters
#
# Tahir has dropped AB at deep square leg  That would have been nail in coffin with Undertaker's music playing, but AB gets a life. Swept from leg-stump, gets a top edge, and Tahir makes a hash of it
#
# back of a length again outside off, but AB has watched and knows the ball holds up. Waits for it and slaps it down to third man gently. Superb from Chahar at the top, just 17 runs in four overs. And would have been 13, if not for a mis-fielded boundary in the first over
#
# down the track and gets to the pitch of the ball to drive powerfully, but straight to Bravo at mid-off, so no run for AB
#
# good length patted into the offside
#
# through him  length ball nipping back in off the seam, and through between AB's bat and body. He was trying to nudge it into the onside
#
# ooh was that a potential catch for Tahir at deep square leg? drags it a bit short, Parthiv pulls but in the air. Tahir decides against running in to dive, and collects on the bounce
#
# back of a length outside off, he stays beside it and glides it to short third man
#
# inside edge onto pad and rolls to slip. Harbhajan is up in appeal, but the edge saved him. Length ball on off, he wanted to cut it, but edged onto pad
#
# fullish length, driven to mid-on
#
# almost an intentional thick outside edge by AB. This was flighted up fuller outside off, the top-spinner and he almost guides it to third man
#
# length ball on the stumps spinning onto pad, flicked off the front foot
#
# popped back to the bowler  tames of dismissals. This one was on the length from where the ball is holding up. It held up even more, pitched on off and spinning away, and Moeen was way too early into his shot, trying to drive. Ends up popping the ball in the air off the end of the bat, and Harbhajan has all the time in the world to pluck the catch over his head. What a start by Harbhajan and Chennai
#
# good length, pitching on off, spinning away, defended into the offside
#
# back of a length on the stumps, Moeen changes tack. He was trying to pull these earlier, but he's content to glide it to third man now. Gliding, nudging and pushing might be the way to go on this pitch, till you get set
#
# upper cut  surprises him wit hthe bouncer, but Parthiv adjusts well to upper cut it over Dhoni. Harbhajan is at third man and collects on the bounce
#
# back of a length on off again, under-edges the pull to deep square leg
#
# he's honed in on that back of length spot again, and the ball's holding up. Parthiv tries to flick it away but a bit early into the shot.
#
# dragged it down a little short, but Moeen doesn't try to pull very fiercely, almost guides it to the man on the square leg boundary, along the ground
#
# back of a length on off stump, he mis-times the pull towards deep square leg
#
# boom  takes an offspinner to read an offspinner! This was fuller, in the sweeping range and Moeen was quickly down on one knee and hit it out of the screws. Superb connection to send the ball into the midwicket stands. Much needed hit for RCB
#
# fuller, driven towards point with an open bat face
#
# beauty to start with. Moeen will appreciate that. On a length outside off, drawing him forward and spinning past
#
# he's got him!  Harbhajan hadn't got a wicket in the last three T20s he played in. What a time and what a wicket to break that duck. Dragged this a little shorter, but it was still spinning into Kohli, who transferred weight back and pulled fiercely. But the ball's not really coming on to the bat, so even though he connected well, he didn't get the distance, and Ravindra Jadeja at deep midwicket stayed still and caught the ball, calm as you please. Chepauk's gone ballistic
#
# ooh the ball's already turning. pitches on a length outside off and holds up, Parthiv ends up getting it off the top half of the bat down to long of with a horizontal bat
#
# good length on off and spinning away. Parthiv wanted to slash it away but under-edges it back to the bowler
#
# brilliant bowling. yorker angling in from slightly wider of the crease to finish and all Kohli can do is dig it back out. Terrific from Chahar
#
# slower one goes wrong  it's slipped out of his hands and gone over Kohli's head, so it's a no-ball. Free hit coming up.
#
# back of a length outside off again, and Kohli is again not able to hit freely through the line or on the up. Driven to mid-off
#
# terrific bowling, he's found that spot from where the ball is holding up a bit, and Kohli is a mite early into his shot. ends up patting it back
#
# good ball, back of a length and on off stump, steered to point, but Jadeja's there and they aren't going to risk a quick single to him.
#
# swing and a miss  this pitch is not conducive to strokeplay perhaps. It held up a bit, length outside off. Kohli wanted to slap through cover, but couldn't connect
#
# back of a length keeps it stump to stump, and the ball doesn't bounce above the knee roll, Kohli comes on the front foot and flicks to deep square leg. The man has to run to his left so they get a couple
#
# flatter on off and spinning in a bit, Kohli moves back and across and wrists it to midwicket
#
# tossed up but on the pads, rolls away to square leg
#
# too short and gets it to bounce so Parthiv can move on the backfoot and cut it fiercely. Too fierce for the man at point to dive and intercept cleanly
#
# fullish on the stumps, Kohli drives gently to a widish long-on
#
# wrong line, too full and on the pads, worked away behind square
#
# length ball on off, Kohli moves across and whips to midwicket
#
# length ball on fifth stump, driven to extra cover. Good start by Chahar, with only one run and a mis-field
#
# misfield by by mid-off  too full and Parthiv cracks an off-drive, but Shardul lets it through his legs while running in to try and attack the ball
#
# fuller and straighter, Parthiv wants to drive, but doesn't get the timing right while driving on the up. The ball trickles to mid-off
#
# good bowling, keeps it wide of off stump but within the tramlines, Parthiv lets it go, but that's not a wide
#
# back of a length ball, given some width outside off. Parthiv slashes hard but can't get past point
#
# strays on the pads first ball and Kohli flicks to fine leg, where Harbhajan is stationed, so only a single

# %% [markdown]
# # Data Preprocessing

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import num2words

D=[]
porter_stemmer = PorterStemmer()

#To tokenize and to convert inot lower case,removal of stop words.
def word_tokenize_all(list):

    punctuations=['+',',','?','!','/','@','#','$']
    tokens=[]

    for lines in list:
        all_words=word_tokenize(lines)
        all_words=map(lambda x:x.lower(),all_words)
        filtered_words = [word for word in all_words if word not in stopwords.words('english')+punctuations]
        stemmed_word=[porter_stemmer.stem(word) for word in filtered_words]
        add_numbers=[num2words.num2words(int(words)) if words.isnumeric() else words  for words in stemmed_word]

        tokens.append(add_numbers)

    return tokens



fp=open('TestingOnIPL.txt','r')

list=[line.replace(',', ' ') for line in fp.readlines()]

D=word_tokenize_all(list)
fp.close()

# %%
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # Applying tf - idf

# %%
import math
from normalization import *
import re

def score(q, d, op_type):

    if op_type=='and':
        if len(set(q).intersection(d))==len(set(q)):
            ret = 0
            for t in q:
                ret += (tf(t, d) * idf(t))

            return ret
        else:
            return 0
    else:
        ret = 0
        for t in q:
            ret += (tf(t, d) * idf(t))
        return ret

# %%
def tf(t, d):
    return float(d.count(t)) / len(d)


def idf(t):
    count_in_doucment = 0
    for d in D:
        if t in d:
            count_in_doucment += 1

    return 0 if count_in_doucment == 0 else math.log(len(D)/float(count_in_doucment))

# %%
while True:
    #dictionary containing top k documents which matches the query term
    scores={}

    query=input('enter the query string: or q to quit\n')
    print ('**************************************************************\n')

    #checking if the query starts with double quotes(exact match)
    if query.startswith('"'):
        op='and'
    else:
        op='or'
        query=re.sub(r'boundary','boundary 4 6',query)
        query=re.sub(r'couple','couple 2',query)

    query=re.sub(r'[#+?!"/@$,]',' ',query)

    if query=='q' or query=='quit':
        break

    query=word_tokenize_all([query])

    i=0
    for d in tqdm_notebook(D,desc = ' progress'):
        #calculating score for each document
        sc=score(query[0],d,op)

        #storing score in the dictionary only if the score > 0
        if sc != 0:
            scores[i]=sc

        i+=1


    if len(scores)==0:
        print( 'no match found')
    else:
        #getting top 5 documents matching the query
        top_docs=sorted(scores, key=scores.get, reverse=True)[:5]

        rank=1
        for id in top_docs:
            print ("rank:",rank,'score',scores[id])
            print (list[id].strip())
            print ("-----------------------------------------------")
            rank+=1
# Out:
# enter the query string: or q to quit
# around the wicket
# **************************************************************
# HBox(children=(HTML(value=' progress'), FloatProgress(value=0.0, max=13522.0), HTML(value='')))
# rank: 1 score 1.3895089930445295
# angles into him from around the wicket  and he runs this down to long on
# -----------------------------------------------
# rank: 2 score 0.9925064236032353
# a carrom ball around off  comes forward and pushes it down the wicket
# -----------------------------------------------
# rank: 3 score 0.9925064236032353
# length around off  Jadhav stays back and defends it down the wicket
# -----------------------------------------------
# rank: 4 score 0.9487613915611004
# length ball on the stumps  comes slower off the wicket  lobbed down the wicket
# -----------------------------------------------
# rank: 5 score 0.9487613915611004
# flatter on the stumps  pushes it down the wicket
# -----------------------------------------------
# enter the query string: or q to quit
# q
# **************************************************************
